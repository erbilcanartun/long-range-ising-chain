# %%
import numpy as np
import matplotlib.pyplot as plt

import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from renormalization import find_Jc

# %%
# Critical point

Jc = find_Jc(
    a=1.5,
    Jlow=1e-2, Jhigh=1e2,
    max_steps=6, max_dist_final=6,
    tol=1e-5,
    growth_threshold=1e4, decay_threshold=1e-4
)
print("Critical Jc =", Jc)
print("Critical Tc =", 1/Jc)
# Out:
# Critical Jc = 0.010002979934215547
# Critical Tc = 99.97020953520706

# %%
# Critical line

a_vals = np.linspace(1, 2, 10)
Jc_vals = []
Tc_vals = []

for a in a_vals:
    Jc = find_Jc(
        a=a,
        Jlow=1e-4, Jhigh=1e4,
        max_steps=8, max_dist_final=9,
        tol=1e-5,
        growth_threshold=1e3, decay_threshold=1e-3
    )
    Jc_vals.append(Jc)
    Tc_vals.append(1.0 / Jc)
    print(f"a = {a:.4f}  →  Jc = {Jc:.3}, Tc = {1/Jc:.3}")

Jc_vals = np.array(Jc_vals)
Tc_vals = np.array(Tc_vals)

plt.figure(figsize=(7,5))
plt.plot(a_vals, Tc_vals, 'o-', ms=5)
plt.ylim(0, 100)
plt.xlabel("a", fontsize=13)
plt.ylabel("1 / Jc (Critical Temperature)", fontsize=13)
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# a = 1.0000  →  Jc = 0.00108, Tc = 9.24e+02
# a = 1.1111  →  Jc = 0.00118, Tc = 8.51e+02
# a = 1.2222  →  Jc = 0.00127, Tc = 7.88e+02
# a = 1.3333  →  Jc = 0.00137, Tc = 7.29e+02
# a = 1.4444  →  Jc = 0.00151, Tc = 6.62e+02
# a = 1.5556  →  Jc = 0.00173, Tc = 5.8e+02
# a = 1.6667  →  Jc = 0.00197, Tc = 5.08e+02
# a = 1.7778  →  Jc = 0.00224, Tc = 4.47e+02
# a = 1.8889  →  Jc = 0.00253, Tc = 3.96e+02
# a = 2.0000  →  Jc = 0.00292, Tc = 3.43e+02
