# %%
import numpy as np
import matplotlib.pyplot as plt

import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from renormalization import find_Jc

# %%
# Critical point

Jc = find_Jc(
    a=1.5,
    Jlow=1e-2, Jhigh=1e2,
    max_steps=6, max_dist_final=6,
    tol=1e-5,
    growth_threshold=1e4, decay_threshold=1e-4
)
print("Critical Jc =", Jc)
print("Critical Tc =", 1/Jc)
# Out:
# Critical Jc = 0.41798577338457105
# Critical Tc = 2.3924259237405727

# %%
# Critical line

a_vals = np.linspace(.8, 2, 10)
Jc_vals = []
Tc_vals = []

for a in a_vals:
    Jc = find_Jc(
        a=a,
        Jlow=1e-4, Jhigh=1e4,
        max_steps=6, max_dist_final=9,
        tol=1e-5,
        growth_threshold=1e3, decay_threshold=1e-3
    )
    Jc_vals.append(Jc)
    Tc_vals.append(1.0 / Jc)
    print(f"a = {a:.4f}  →  Jc = {Jc:.3}, Tc = {1/Jc:.3}")

Jc_vals = np.array(Jc_vals)
Tc_vals = np.array(Tc_vals)

plt.figure(figsize=(7,5))
plt.plot(a_vals, Tc_vals, 'o-', ms=5)
plt.ylim(0, 100)
plt.xlabel("a", fontsize=13)
plt.ylabel("1 / Jc (Critical Temperature)", fontsize=13)
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# a = 0.8000  →  Jc = 0.018, Tc = 55.5
# a = 0.9333  →  Jc = 0.0918, Tc = 10.9
# a = 1.0667  →  Jc = 0.164, Tc = 6.1
# a = 1.2000  →  Jc = 0.237, Tc = 4.22
# a = 1.3333  →  Jc = 0.314, Tc = 3.19
# a = 1.4667  →  Jc = 0.396, Tc = 2.52
# a = 1.6000  →  Jc = 0.488, Tc = 2.05
# a = 1.7333  →  Jc = 0.594, Tc = 1.68
# a = 1.8667  →  Jc = 0.721, Tc = 1.39
# a = 2.0000  →  Jc = 0.883, Tc = 1.13
