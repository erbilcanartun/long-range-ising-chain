# %%
# %%time
# Use case example: Plot phase diagram for the spin-glass Ising model (using renormalization_sg.py)
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from spinglass import *

a = 1.0  # Exponent a (n in code)
L = 22
one_over_J_values = np.linspace(0.01, 4.0, L)  # 1/J
p_values = np.linspace(0.0, 1.0, L)  # Probability p for antiferromagnetic bonds
ms = 5
Disorder_Phase, Ferro_Phase, Undecided_Phase = plot_phase_diagram(
    a, p_values, one_over_J_values,
    max_k=1000, skip_steps=3, track_rs=[2]
)
# Out:
# 100%|██████████| 22/22 [01:28<00:00,  4.03s/it]
# CPU times: user 1min 27s, sys: 300 ms, total: 1min 28s
# Wall time: 1min 28s
