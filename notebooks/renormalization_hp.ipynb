# %%
import numpy as np
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from renormalization_hp import *

# %%
# %%time

generate_rg_flow(
    J0=.2, n=1.5,
    max_k=1000, num_steps=7,
    show_first=0, num_r_to_plot=3
)
# Out:
# CPU times: user 16.2 s, sys: 96.5 ms, total: 16.3 s
# Wall time: 16.6 s

# %%
# %%time
J = .4
n = 1.5

plot_rg_steps_vs_r(
    J0=J, n=n,
    max_k=10000, num_steps=7, plot_up_to_r=5, colormap=False, fig_name=f'J={J},n={n}.png'
)
# Out:
# CPU times: user 2min 37s, sys: 304 ms, total: 2min 37s
# Wall time: 2min 37s

# %% [markdown]
# ## Critical point

# %%
find_J_c(
    n=1.7, max_k=5000,
    tol=1e-4, J_low=0.001, J_high=3.0
)

# %%
n_values = np.linspace(.8, 1.9, 15, True)
n_values
# Out:
# array([0.8       , 0.87857143, 0.95714286, 1.03571429, 1.11428571,
#        1.19285714, 1.27142857, 1.35      , 1.42857143, 1.50714286,
#        1.58571429, 1.66428571, 1.74285714, 1.82142857, 1.9       ])

# %%
plot_J_c_vs_n(n_values, max_k=2000, tol=1e-4)
