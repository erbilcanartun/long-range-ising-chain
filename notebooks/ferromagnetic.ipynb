# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from renormalization import *

# %%
plot_first_renormalized_J(10, 1.0, 2.0)
# Out:
# For cluster 1 (right starting at 4), J' = 1.3554138674936338
# For cluster 2 (right starting at 7), J' = 0.22584844321562483
# For cluster 3 (right starting at 10), J' = 0.09392484793281192
# For cluster 4 (right starting at 13), J' = 0.05168794243237164
# For cluster 5 (right starting at 16), J' = 0.03275395738063411
# For cluster 6 (right starting at 19), J' = 0.022624969606377204
# For cluster 7 (right starting at 22), J' = 0.0165694525624952
# For cluster 8 (right starting at 25), J' = 0.012659832368186389
# For cluster 9 (right starting at 28), J' = 0.009988722668634464
# For cluster 10 (right starting at 31), J' = 0.008082715713826698

# %%
plot_non_renormalized_J(1.2, 2.3, 10)

# %%
plot_both(.3, 2.5, max_k=20)
# Out:
# For cluster 1 (effective r=1), J' = 0.1714046802218676
# For cluster 2 (effective r=2), J' = 0.01404914187004575
# For cluster 3 (effective r=3), J' = 0.004641814271072398
# For cluster 4 (effective r=4), J' = 0.002193200337930116
# For cluster 5 (effective r=5), J' = 0.0012382919363685557
# For cluster 6 (effective r=6), J' = 0.0007792232486914782
# For cluster 7 (effective r=7), J' = 0.0005276842207635749
# For cluster 8 (effective r=8), J' = 0.0003768364805481896
# For cluster 9 (effective r=9), J' = 0.0002801709052673731
# For cluster 10 (effective r=10), J' = 0.00021499260257192829
# For cluster 11 (effective r=11), J' = 0.00016923657777993017
# For cluster 12 (effective r=12), J' = 0.00013604506310113367
# For cluster 13 (effective r=13), J' = 0.00011130459768234959
# For cluster 14 (effective r=14), J' = 9.243612381478202e-05
# For cluster 15 (effective r=15), J' = 7.776149541549845e-05
# For cluster 16 (effective r=16), J' = 6.615375296425714e-05
# ...

# %%
generate_rg_flow(3, 1.5, 100, 10, show_first=0, num_r_to_plot=5)
