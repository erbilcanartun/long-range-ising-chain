# %%
import numpy as np
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from renormalization_hp_aferro import *

# %%
# %%time

generate_rg_flow(
    J0=-1, n=.5,
    max_k=1000, num_steps=20,
    show_first=0, num_r_to_plot=7
)
# Out:
# CPU times: user 31.6 s, sys: 50.6 ms, total: 31.7 s
# Wall time: 31.7 s

# %%
# %%time
J = .1
n = 1

plot_rg_steps_vs_r(
    J0=J, n=n,
    max_k=10000, num_steps=7, plot_up_to_r=5, colormap=False, fig_name=f'J={J},n={n}.png'
)
# Out:
# CPU times: user 2min 56s, sys: 1.28 s, total: 2min 57s
# Wall time: 3min 1s

# %% [markdown]
# ## Critical point

# %%
find_J_c(
    n=1.7, max_k=5000,
    tol=1e-4, J_low=0.001, J_high=3.0
)

# %%
n_values = np.linspace(.01, 2, 30, True)
n_values
# Out:
# array([0.01      , 0.07862069, 0.14724138, 0.21586207, 0.28448276,
#        0.35310345, 0.42172414, 0.49034483, 0.55896552, 0.62758621,
#        0.6962069 , 0.76482759, 0.83344828, 0.90206897, 0.97068966,
#        1.03931034, 1.10793103, 1.17655172, 1.24517241, 1.3137931 ,
#        1.38241379, 1.45103448, 1.51965517, 1.58827586, 1.65689655,
#        1.72551724, 1.79413793, 1.86275862, 1.93137931, 2.        ])

# %%
# %%time

plot_J_c_vs_n(n_values, max_k=2000, tol=1e-6)
# Out:
# For n=0.01, J_c=0.001000715017318725606754176748638009814777
# For n=0.07862068965517241, J_c=0.001000715017318725606754176748638009814777
# For n=0.14724137931034484, J_c=0.001000715017318725606754176748638009814777
# For n=0.21586206896551724, J_c=0.001000715017318725606754176748638009814777
# For n=0.28448275862068967, J_c=0.001000715017318725606754176748638009814777
# For n=0.3531034482758621, J_c=0.001000715017318725606754176748638009814777
# For n=0.42172413793103447, J_c=0.001000715017318725606754176748638009814777
# For n=0.4903448275862069, J_c=0.001000715017318725606754176748638009814777
# For n=0.5589655172413793, J_c=0.001000715017318725606754176748638009814777
# For n=0.6275862068965518, J_c=0.001000715017318725606754176748638009814777
# For n=0.6962068965517242, J_c=0.001000715017318725606754176748638009814777
# For n=0.7648275862068966, J_c=0.01492925238609313966915749587864281194014
# For n=0.8334482758620689, J_c=0.08157029652595520021556992655393580822802
# ...
