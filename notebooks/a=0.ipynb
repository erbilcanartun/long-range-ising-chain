# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'lib')))
from a0 import *
import matplotlib.pyplot as plt

# %%
J0 = 20
steps = 5

flow = rg_flow_a0(J0, n_steps=steps)

plt.figure(figsize=(7,5))
plt.plot(range(steps+1), flow, '-o')
plt.xlabel("RG step")
plt.ylabel("Coupling J")
plt.title("a = 0 RG flow with 15 interactions (2×3-spin block)")
plt.grid(False)
plt.show()

# %% [markdown]
# # Magnetization

# %%
Ts, Ms = sweep_magnetization(0.01, 100, 300)

plt.figure(figsize=(7,5))
plt.plot(Ts, Ms, '-')
plt.xlabel("Temperature T")
plt.ylabel("Magnetization M(T)")
plt.xlim(0, 100)
plt.ylim(0, 1.05)
plt.grid(False)
plt.show()
